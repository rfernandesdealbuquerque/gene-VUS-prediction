# %%
import datetime
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from data import prepare_data
from src import evaluate_models, make_figures, run_models
import main

#Custom imports
from src import evaluate_models, make_figures, run_models
from utils import get_best_hyperparameters, get_median_model_seed

# %%
runstudy_lr_1 = main.RunStudy('KCNQ1', 'grid_search', 'LR', iterations=200)
# runstudy_lr_2 = main.RunStudy('MYH7', 'grid_search', 'LR', iterations=200)
# runstudy_lr_3 = main.RunStudy('RYR2', 'grid_search', 'LR', iterations=200)
# Out:
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.8787012987012988
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9442532467532467
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9743614718614719
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9529870129870132
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9392965367965367
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# ...

# %%
runstudy_rf_1 = main.RunStudy('KCNQ1', 'rand_search', 'RandomForest', iterations=200)
