# %%
import datetime
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from data import prepare_data
from src import evaluate_models, make_figures, run_models
import main

#Custom imports
from src import evaluate_models, make_figures, run_models
from utils import get_best_hyperparameters, get_median_model_seed

# %%
runstudy_lr_1 = main.RunStudy('KCNQ1', 'grid_search', 'LR', iterations=10)
# runstudy_lr_2 = main.RunStudy('MYH7', 'grid_search', 'LR', iterations=200)
# runstudy_lr_3 = main.RunStudy('RYR2', 'grid_search', 'LR', iterations=200)
# Out:
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9326406926406927
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.940487012987013
# Best LR Params: {'C': 100, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.971482683982684
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9337012987012987
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9613852813852815
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9370779220779222
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9335064935064935
# Best LR Params: {'C': 10000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9403679653679655
# Best LR Params: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.925952380952381
# Best LR Params: {'C': 100000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# *** Preparing data for KCNQ1 ***
#
# *** Running  LR ***
# Best K-fold Auc: 0.9600757575757575
# Best LR Params: {'C': 1000, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#      Seed  Best K-fold AUC  Train AUC  Test AUC Penalty       C     Solver
# 8  100916         0.925952   0.973513  0.991143      l1  100000  liblinear
# 6  166504         0.933506   0.973886  0.988728      l1   10000  liblinear
# 3   25780         0.933701   0.975694  0.976651      l1   10000  liblinear
# 0   52947         0.932641   0.977502  0.958132      l1  100000  liblinear
# 1  268996         0.940487   0.975907  0.956522      l1     100  liblinear
# 5   14584         0.937078   0.980215  0.954911      l1  100000  liblinear
# 9   40868         0.960076   0.981438  0.954106      l1    1000  liblinear
# 7     513         0.940368   0.978672  0.945250      l2     100  liblinear
# 2   31933         0.971483   0.981810  0.892110      l1  100000  liblinear
# 4  218964         0.961385   0.983246  0.888084      l1   10000  liblinear
#   Penalty       C     Solver  mean  count  weight  score
# 0      l1     100  liblinear  0.96      1     0.1  0.096
# 1      l1    1000  liblinear  0.95      1     0.1  0.095
# 2      l1   10000  liblinear  0.95      3     0.3  0.285
# 3      l1  100000  liblinear  0.95      4     0.4  0.380
# 4      l2     100  liblinear  0.95      1     0.1  0.095
#   Penalty       C     Solver  best avg AUC  weight  overall avg AUC
# 0      l1  100000  liblinear          0.95     0.4             0.95
# ['Penalty', 'C', 'Solver']
#      Seed  Best K-fold AUC  Train AUC  Test AUC Penalty       C     Solver
# 8  100916         0.925952   0.973513  0.991143      l1  100000  liblinear
# 0   52947         0.932641   0.977502  0.958132      l1  100000  liblinear
# 5   14584         0.937078   0.980215  0.954911      l1  100000  liblinear
# 2   31933         0.971483   0.981810  0.892110      l1  100000  liblinear
# 14584
# *** Preparing data for KCNQ1 ***
# Penalty: l1
# C: 100000
# Solver: liblinear
# best avg AUC: 0.95
# weight: 40.0 %
# overall avg AUC: 0.95

# %%
runstudy_rf_1 = main.RunStudy('KCNQ1', 'rand_search', 'RandomForest', iterations=200)
