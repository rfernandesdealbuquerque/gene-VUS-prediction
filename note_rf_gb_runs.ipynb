# %%
import datetime
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from data import prepare_data
from src import evaluate_models, make_figures, run_models
import main

#Custom imports
from src import evaluate_models, make_figures, run_models
from utils import get_best_hyperparameters, get_median_model_seed

# %%
runstudy_rf_1 = main.RunStudy('KCNQ1', 'rand_search', 'RandomForest', iterations=1000)

# %%
runstudy_rf_2 = main.RunStudy('MYH7', 'rand_search', 'RandomForest', iterations=1000)

# %%
runstudy_rf_3 = main.RunStudy('RYR2', 'rand_search', 'RandomForest', iterations=1000)

# %%
runstudy_gb_1 = main.RunStudy('KCNQ1', 'rand_search', 'GradientBoosting', iterations=3)
# Out:
# *** Preparing data for KCNQ1 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9477380952380953
# Best GradientBoosting Params: {'subsample': 0.8, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 6, 'learning_rate': 0.15}
# *** Preparing data for KCNQ1 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9641125541125541
# Best GradientBoosting Params: {'subsample': 0.8, 'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 6, 'learning_rate': 0.1}
# *** Preparing data for KCNQ1 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9485389610389611
# Best GradientBoosting Params: {'subsample': 0.9, 'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 6, 'learning_rate': 0.15}
#      Seed  Best K-fold AUC  Train AUC  Test AUC  n_estimators  learning_rate  \
# 0  122800         0.947738        1.0  0.957729           100           0.15
# ...

# %%
runstudy_gb_2 = main.RunStudy('MYH7', 'rand_search', 'GradientBoosting', iterations=3)
# Out:
# *** Preparing data for MYH7 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.859
# Best GradientBoosting Params: {'subsample': 0.9, 'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 6, 'learning_rate': 0.2}
# *** Preparing data for MYH7 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.849
# Best GradientBoosting Params: {'subsample': 0.9, 'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 6, 'learning_rate': 0.1}
# *** Preparing data for MYH7 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.8955384615384615
# Best GradientBoosting Params: {'subsample': 0.9, 'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 4, 'learning_rate': 0.1}
#      Seed  Best K-fold AUC  Train AUC  Test AUC  n_estimators  learning_rate  \
# 1   62932         0.849000        1.0  0.984127            50            0.1
# ...

# %%
runstudy_gb_3 = main.RunStudy('RYR2', 'rand_search', 'GradientBoosting', iterations=3)
# Out:
# *** Preparing data for RYR2 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9649999999999999
# Best GradientBoosting Params: {'subsample': 0.6, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 6, 'learning_rate': 0.1}
# *** Preparing data for RYR2 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9901190476190477
# Best GradientBoosting Params: {'subsample': 0.8, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_depth': 4, 'learning_rate': 0.2}
# *** Preparing data for RYR2 ***
#
# *** Running  GradientBoosting ***
# Best K-Fold Auc: 0.9771428571428571
# Best GradientBoosting Params: {'subsample': 0.6, 'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 4, 'learning_rate': 0.15}
#      Seed  Best K-fold AUC  Train AUC  Test AUC  n_estimators  learning_rate  \
# 0  125685         0.965000   0.999599  0.992629           100           0.10
# ...
